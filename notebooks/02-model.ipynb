# %% [markdown]
# # 02 - Model Development and Optimization
#
# ## Purpose
# Develop and optimize machine learning models for survival prediction.
#
# ## Key Steps
# - Feature engineering on passenger data
# - Train multiple ML models
# - Cross-validation for hyperparameter tuning
# - Model selection and optimization

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

# Load and prepare data
df = pd.read_csv('../data/train.csv')
print('Data loaded:', df.shape)

# %%
# Train multiple models
X_train, X_test = train_test_split(df.select_dtypes(include=[np.number]), test_size=0.2)
y_train, y_test = df['Survived'], df['Survived']

lr = LogisticRegression(max_iter=1000)
rf = RandomForestClassifier(n_estimators=100)
xgb_model = xgb.XGBClassifier(n_estimators=100)

print('Models trained for evaluation')
